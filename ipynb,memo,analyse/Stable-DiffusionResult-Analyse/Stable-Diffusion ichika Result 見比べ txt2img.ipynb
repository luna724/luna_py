# %% [markdown]
# # Part 1
#     # Generate
#         Prompt: ((anime-style:1.5)), black hair, star hair accessory, standing, looking at viewer, ((black-to-aqua gradient eyes)), white skin, Project Sekai character, Ichika Hoshino, ((Starry Sky background)), one character, ((clothes unchanged)) <lora:ick_selected_solo_0205:1>
#
#         Negative Prompt: lowres, bad anatomy, text, bad face, error, extra digit, fewer digits, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, {blurry}, missing arms, missing legs, more than two legs,
#
#         Width, Height = 1024,1024  |  Batch Count / Size = 5,2
#         CFG Scale = 7  |  Seed = -1
#         Restore faces: False  |  Tilling: False  |  Hires.fix: False
#         Sampling method: DPM++ SDE Karras   |   Sampling Steps: 30
#         Other Advanced Settings: Default
#
#     # 問題点 / Issue
#         足が2本以上ある。顔が少し崩れている。二人以上生成されている。
#         背景不明。
#
#     # 傑作だと思うもの
#         5, 8, 9
# ![Sample](https://raw.githubusercontent.com/luna724/for-ipynb/main/ipynb/part1.jpg)

# %% [markdown]
# # Part 2
#     # Generate
#         Prompt: ((anime-style:1.5)), black hair, star hair accessory, standing, looking at viewer, ((black-to-aqua gradient eyes)), white skin, Project Sekai character, Ichika Hoshino, ((No background)), one character, ((clothes unchanged)) <lora:ick_selected_solo_0205:1>
#
#         Negative Prompt: lowres, bad anatomy, text, bad face, error, extra digit, fewer digits, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, {blurry}, missing arms, missing legs, more than two legs,
#
#         Width, Height = 1024,1024  |  Batch Count / Size = 2,5
#         CFG Scale = 7  |  Seed = -1
#         Restore faces: True  |  Tilling: True  |  Hires.fix: False
#         Sampling method: DPM++ SDE Karras   |   Sampling Steps: 30
#         Other Advanced Settings: Default
#
#     # 問題点 / Issue
#         Starry Sky Background -> No Backgroundにしたこと
#         背景の消失とともに、全体像の消滅が見られた
#         No ** はすべて使わない方がいいということがわかったと同時に、必須要素は No ** とNegative
#         に入れればいいことを理解した
#
#     # 傑作だと思うもの
#         なし
# ![Sample](https://raw.githubusercontent.com/luna724/for-ipynb/main/ipynb/part2.jpg)

# %% [markdown]
# # Part 3
#     # Generate
#         Prompt: ((anime-style:1.5)), black hair, star hair accessory, standing, looking at viewer, ((black-to-aqua gradient eyes)), white skin, Project Sekai character, Ichika Hoshino, ((Starry Sky background)), one character, ((clothes unchanged)) <lora:ick_selected_solo_0205:1>
#
#         Negative Prompt: lowres, bad anatomy, text, bad face, error, extra digit, fewer digits, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, {blurry}, missing arms, missing legs, more than two legs,
#
#         Width, Height = 1024,1024  |  Batch Count / Size = 5,2
#         CFG Scale = 7  |  Seed = -1
#         Restore faces: True  |  Tilling: True  |  Hires.fix: False
#         Sampling method: DPM++ SDE Karras   |   Sampling Steps: 30
#         Other Advanced Settings: Default
#
#     # 問題点 / Issue
#         問題点は、No Background ではなく、 Tilling であると思われる
#
#     # 傑作だと思うもの
#         なし
# ![Sample](https://raw.githubusercontent.com/luna724/for-ipynb/main/ipynb/part3.jpg)

# %% [markdown]
# # Part 4
#     # Generate
#         Prompt: ((anime-style:1.5)), black hair, star hair accessory, standing, looking at viewer, ((black-to-aqua gradient eyes)), white skin, Project Sekai character, Ichika Hoshino, ((Starry Sky background)), one character,,  <lora:ick_selected_solo_0205:1>
#
#         Negative Prompt: lowres, bad anatomy, text, bad face, error, extra digit, fewer digits, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, {blurry}, missing arms, missing legs, more than two legs,
#
#         Width, Height = 1024,1024  |  Batch Count / Size = 5,2
#         CFG Scale = 7  |  Seed = -1
#         Restore faces: True  |  Tilling: False  |  Hires.fix: False
#         Sampling method: DPM++ SDE Karras   |   Sampling Steps: 30
#         Other Advanced Settings: Default
#
#     # 問題点 / Issue
#         顔を正確に指定してあげないと、ダメっぽい
#         別キャラ感があまりないのがすごいけど、服装に一貫性が見られない。　指定してあげないと
#         背景がよくわからない
#         やっぱり、二人以上の描写が見られる。
#
#
#     # 傑作だと思うもの
#         5, 7
# ![Sample](https://raw.githubusercontent.com/luna724/for-ipynb/main/ipynb/part4.png)

# %% [markdown]
# # Part 5
#     # Generate
#         Prompt: ((anime-style:1.9)), ((black hair with star hair accessory:1.5)), looking at viewer, (black-to-aqua gradient eyes), white skin, Project Sekai character, Ichika Hoshino, one character, lying on the plains in white plain long-sleeved clothing, Drawing from a little above the subject, Drawing a single character only,, <lora:ick_selected_solo_0205:1>
#
#         Negative Prompt: lowres, bad anatomy, text, bad face, error, extra digit, fewer digits, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, {blurry}, missing arms, missing legs, more than two legs, unfocused eyes, eyes wandering, lack of eye contact, Avoid depicting multiple characters,
#
#         Width, Height = 1280,1280  |  Batch Count / Size = 5,2
#         CFG Scale = 7  |  Seed = -1
#         Restore faces: True  |  Tilling: False  |  Hires.fix: False
#         Sampling method: DPM++ SDE Karras   |   Sampling Steps: 50
#         Stable Diffusion Checkpoint: CounterfeltV25_25
#         Other Advanced Settings: Default
#
#     # 問題点 / Issue
#         !Write Issue Here
#
#     # 傑作だと思うもの
#         !Write Masterpiece Here
#
# ![Sample](https://raw.githubusercontent.com/luna724/for-ipynb/main/ipynb/part5.png)

# %% [markdown]
# # Part 6
#     # Generate
#         Prompt: ((anime-style:1.9)), ((black hair with star hair accessory:1.5)), looking at viewer, (black-to-aqua gradient eyes), white skin, Project Sekai character, Ichika Hoshino, one character, lying on the plains in white plain long-sleeved clothing, Drawing from a little above the subject, Drawing a single character only,, <lora:ick_selected_solo_0205:1>
#
#         Negative Prompt: lowres, bad anatomy, text, bad face, error, extra digit, fewer digits, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, {blurry}, missing arms, missing legs, more than two legs, unfocused eyes, eyes wandering, lack of eye contact, Avoid depicting multiple characters,
#
#         Width, Height = 1280,1280  |  Batch Count / Size = 5,2
#         CFG Scale = 7  |  Seed = 29041809
#         Restore faces: True  |  Tilling: False  |  Hires.fix: False
#         Sampling method: DPM++ SDE Karras   |   Sampling Steps: 50
#         Stable Diffusion Checkpoint: CounterfeltV25_25
#         Other Advanced Settings: Default
#
#     # 問題点 / Issue
#         背景をかけないっぽい、背景と関連するキャラの指定はやめた方がよさそう
#         プロンプトの問題かもしれないが、CounterfeltV25_25を使用すると、画像の規則性、正しい描画ができていない。
#         アニメスタイル、ヘアスタイルの過度な指定も問題ともみられる
#         また、顔は用追加学習または、img2img使用必須かもしれない
#         さらに、服装もしっかりと学習できていなさそうなので、指定はしない方がよさそう
#
#     # 傑作だと思うもの
#         !Write Masterpiece Here
#
# ![Sample](https://raw.githubusercontent.com/luna724/for-ipynb/main/ipynb/part6.png)

# %% [markdown]
# # # # 新たなモデルはこの下!

# %% [markdown]
# # Part 8
#     # Generate
#         Prompt: - The character has waist-length black hair. - She is a girl named Ichika from Project Sekai. - She has black to light blue gradient eyes from the top. - She has white skin. - The background features a beautiful blue sky. - She is standing alone and smiling at us. - Her hair is a faint blue color in the light. - She has long, straight, waist-length black hair with bangs styled to keep them out of her eyes. - She wears a white and blue marine-style outfit. - The outfit includes a short blue and white skirt above the knee. - The outfit has short sleeves. - The design of the outfit is somewhat high school uniform style
#
#         Negative Prompt: - Low resolution - Obscurity - Image noise - Print moiré - Blurring - Image distortion - Tint shift - Image blurring - JPEG artifacts - Hidden elements - Missing areas - Unnatural proportions - Textural clutter - Improper lighting - Occlusion - Out of proportion - Anatomy not accurate - Line drawings disturbed - Unnatural coloration - Lack of detail - Odd poses - Botched facial expressions - Eyes and mouth in the wrong position - Messy hair depiction - Out of proportion - Unnatural handling of shadows and light - Poor quality line art - Coarse drawing touches - Depiction of more than two people - More than two legs or arms - Text - Signatures - Usernames - Mirrors
#
#         Width, Height = 512,512  |  Batch Count / Size = 8,2
#         CFG Scale = 9  |  Seed = 85
#         Restore faces: True  |  Tilling: False  |  Hires.fix: False
#         Sampling method: DPM++ 2M SDE   |   Sampling Steps: 60
#         Stable Diffusion Checkpoint: AbyssOrangeMix2_nsfw_pruned_fp16_with_VAI
#         Other Advanced Settings: Default
#
#     # 問題点 / Issue
#         !Write Issue Here
#
#     # 傑作だと思うもの
#         !Write Masterpiece Here
#
# ![Sample](ipynb/part.8.png)

# %% [markdown]
# # Part 9
#     # Generate
#         Prompt: - The character has waist-length black hair. - She is a girl named Ichika from Project Sekai. - She has black to light blue gradient eyes from the top. - She has white skin. - The background features a beautiful blue sky. - She is standing alone and smiling at us. - Her hair is a faint blue color in the light. - She has long, straight, waist-length black hair with bangs styled to keep them out of her eyes. - She wears a white and blue marine-style outfit. - The outfit includes a short blue and white skirt above the knee. - The outfit has short sleeves. - The design of the outfit is somewhat high school uniform style <lora:test:1>
#
#         Negative Prompt: - Low resolution - Obscurity - Image noise - Print moiré - Blurring - Image distortion - Tint shift - Image blurring - JPEG artifacts - Hidden elements - Missing areas - Unnatural proportions - Textural clutter - Improper lighting - Occlusion - Out of proportion - Anatomy not accurate - Line drawings disturbed - Unnatural coloration - Lack of detail - Odd poses - Botched facial expressions - Eyes and mouth in the wrong position - Messy hair depiction - Out of proportion - Unnatural handling of shadows and light - Poor quality line art - Coarse drawing touches - Depiction of more than two people - More than two legs or arms - Text - Signatures - Usernames - Mirrors
#
#         Width, Height = 512,512  |  Batch Count / Size = 12,4
#         CFG Scale = 9  |  Seed = 85
#         Restore faces: True  |  Tilling: False  |  Hires.fix: False
#         Sampling method: DPM++ 2M SDE   |   Sampling Steps: 100
#         Stable Diffusion Checkpoint: AbyssOrangeMix2_nsfw_pruned_fp16_with_VAI
#         Other Advanced Settings: Default
#
#     # 問題点 / Issue
#         !Write Issue Here
#
#     # 傑作だと思うもの
#         !Write Masterpiece Here
#
# ![Sample](ipynb/part.9.png)

# %% [markdown]
# # Part 10
#     # Generate
#         Prompt: - The character has waist-length black hair. - She is a girl named Ichika from Project Sekai. - She has black to light blue gradient eyes from the top. - She has white skin. - The background features a beautiful blue sky. - She is standing alone and smiling at us. - Her hair is a faint blue color in the light. - She has long, straight, waist-length black hair with bangs styled to keep them out of her eyes. - She wears a white and blue marine-style outfit. - The outfit includes a short blue and white skirt above the knee. - The outfit has short sleeves. - The design of the outfit is somewhat high school uniform style <lora:test:1>
#
#         Negative Prompt: - Low resolution - Obscurity - Image noise - Print moiré - Blurring - Image distortion - Tint shift - Image blurring - JPEG artifacts - Hidden elements - Missing areas - Unnatural proportions - Textural clutter - Improper lighting - Occlusion - Out of proportion - Anatomy not accurate - Line drawings disturbed - Unnatural coloration - Lack of detail - Odd poses - Botched facial expressions - Eyes and mouth in the wrong position - Messy hair depiction - Out of proportion - Unnatural handling of shadows and light - Poor quality line art - Coarse drawing touches - Depiction of more than two people - More than two legs or arms - Text - Signatures - Usernames - Mirrors
#
#         Width, Height = 512,512  |  Batch Count / Size = 12,3
#         CFG Scale = 9  |  Seed = 85
#         Restore faces: True  |  Tilling: False  |  Hires.fix: False
#         Sampling method: Euler a  |   Sampling Steps: 100
#         Stable Diffusion Checkpoint: AbyssOrangeMix2_nsfw_pruned_fp16_with_VAI
#         Other Advanced Settings: Default
#
#     # 問題点 / Issue
#         服装指定がうまくできていない
#         顔がちょっとおかしかったりするものがある
#         なぜか下半身のみ生成される部分が多い
#         なんか顔が一部いっちゃんっぽくない
#         画像の一部が崩れている
#         なんか笑えてない
#
#     # 傑作だと思うもの
#         5, 6, 9, 19, 28
#
# ![Sample](ipynb/part.10.png)

# %% [markdown]
# # Part 11
#     # Generate
#         Prompt: - The character has waist-length black hair. - She is a girl named Ichika from Project Sekai. - She has black to light blue gradient eyes from the top. - She has white skin. - The background features a beautiful blue sky. - She is standing alone and smiling at us. - Her hair is a faint blue color in the light. - She has long, straight, waist-length black hair with bangs styled to keep them out of her eyes. - She wears a white and blue marine-style outfit. - The outfit includes a short blue and white skirt above the knee. - The outfit has short sleeves. - The design of the outfit is somewhat high school uniform style <lora:test:1>
#
#         Negative Prompt: - Low resolution - Obscurity - Image noise - Print moiré - Blurring - Image distortion - Tint shift - Image blurring - JPEG artifacts - Hidden elements - Missing areas - Unnatural proportions - Textural clutter - Improper lighting - Occlusion - Out of proportion - Anatomy not accurate - Line drawings disturbed - Unnatural coloration - Lack of detail - Odd poses - Botched facial expressions - Eyes and mouth in the wrong position - Messy hair depiction - Out of proportion - Unnatural handling of shadows and light - Poor quality line art - Coarse drawing touches - Depiction of more than two people - More than two legs or arms - Text - Signatures - Usernames - Mirrors
#
#         Width, Height = 512,512  |  Batch Count / Size = 12,3
#         CFG Scale = 9  |  Seed = 85
#         Restore faces: True  |  Tilling: False  |  Hires.fix: False
#         Sampling method: Euler  |   Sampling Steps: 100
#         Stable Diffusion Checkpoint: AbyssOrangeMix2_nsfw_pruned_fp16_with_VAI
#         Other Advanced Settings: Default
#
#     # 問題点 / Issue
#         服装指定がうまくできていない
#         顔がちょっとおかしかったりするものがある
#         なぜか下半身のみ生成される部分が多い
#         なんか顔が一部いっちゃんっぽくない
#
#     # 傑作だと思うもの
#         32, 36
#
# ![Sample](ipynb/part.11.png)

# %% [markdown]
# # Part 12
#     # Generate
#         Prompt: - The character has waist-length black hair. - She is a girl named Ichika from Project Sekai. - She has black to light blue gradient eyes from the top. - She has white skin. - The background features a beautiful blue sky. - She is standing alone and smiling at us. - Her hair is a faint blue color in the light. - She has long, straight, waist-length black hair with bangs styled to keep them out of her eyes. - She is completely naked. <lora:test:1>
#
#         Negative Prompt: - Low resolution - Obscurity - Image noise - Print moiré - Blurring - Image distortion - Tint shift - Image blurring - JPEG artifacts - Hidden elements - Missing areas - Unnatural proportions - Textural clutter - Improper lighting - Occlusion - Out of proportion - Anatomy not accurate - Line drawings disturbed - Unnatural coloration - Lack of detail - Odd poses - Botched facial expressions - Eyes and mouth in the wrong position - Messy hair depiction - Out of proportion - Unnatural handling of shadows and light - Poor quality line art - Coarse drawing touches - Depiction of more than two people - More than two legs or arms - Text - Signatures - Usernames - Mirrors
#
#         Width, Height = 512,512  |  Batch Count / Size = 15,2
#         CFG Scale = 9  |  Seed = 85
#         Restore faces: True  |  Tilling: False  |  Hires.fix: False
#         Sampling method: DPM++ 2M Karras   |   Sampling Steps: 120
#         Stable Diffusion Checkpoint: AbyssOrangeMix2
#         Other Advanced Settings: Default
#
#     # 問題点 / Issue
#         !Write Issue Here
#
#     # 傑作だと思うもの
#         !Write Masterpiece Here
#
# ![Sample](ipynb/part.12.png)

# %% [markdown]
# # Part 13
#     # Generate
#         Prompt: - The character has waist-length black hair. - She is a girl named Ichika from Project Sekai. - She has black to light blue gradient eyes from the top. - She has white skin. - The background features a beautiful blue sky. - She is standing alone and smiling at us. - Her hair is a faint blue color in the light. - She has long, straight, waist-length black hair with bangs styled to keep them out of her eyes. - She is completely naked. <lora:test:1>
#
#         Negative Prompt: - Low resolution - Obscurity - Image noise - Print moiré - Blurring - Image distortion - Tint shift - Image blurring - JPEG artifacts - Hidden elements - Missing areas - Unnatural proportions - Textural clutter - Improper lighting - Occlusion - Out of proportion - Anatomy not accurate - Line drawings disturbed - Unnatural coloration - Lack of detail - Odd poses - Botched facial expressions - Eyes and mouth in the wrong position - Messy hair depiction - Out of proportion - Unnatural handling of shadows and light - Poor quality line art - Coarse drawing touches - Depiction of more than two people - More than two legs or arms - Text - Signatures - Usernames - Mirrors
#
#         Width, Height = 512,512  |  Batch Count / Size = 15,2
#         CFG Scale = 9  |  Seed = 85
#         Restore faces: True  |  Tilling: False  |  Hires.fix: 不明 (多分True)
#         Sampling method: DPM++ 2M Karras   |   Sampling Steps: 120
#         Stable Diffusion Checkpoint: AbyssOrangeMix2
#         Other Advanced Settings: Default
#
#     # 問題点 / Issue
#         !Write Issue Here
#
#     # 傑作だと思うもの
#         !Write Masterpiece Here
#
# ![Sample](ipynb/part.13.png)

# %% [markdown]
# # Part 14
#     # Generate
#         Prompt: - The character has waist-length black hair. - She is a girl named Ichika from Project Sekai. - She has black to light blue gradient eyes from the top. - She has white skin. - The background features a beautiful blue sky. - She is standing alone and smiling at us. - Her hair is a faint blue color in the light. - She has long, straight, waist-length black hair with bangs styled to keep them out of her eyes. - She is completely naked. <lora:test:1>
#
#         Negative Prompt: - Low resolution - Obscurity - Image noise - Print moiré - Blurring - Image distortion - Tint shift - Image blurring - JPEG artifacts - Hidden elements - Missing areas - Unnatural proportions - Textural clutter - Improper lighting - Occlusion - Out of proportion - Anatomy not accurate - Line drawings disturbed - Unnatural coloration - Lack of detail - Odd poses - Botched facial expressions - Eyes and mouth in the wrong position - Messy hair depiction - Out of proportion - Unnatural handling of shadows and light - Poor quality line art - Coarse drawing touches - Depiction of more than two people - More than two legs or arms - Text - Signatures - Usernames - Mirrors
#
#         Width, Height = 512,512  |  Batch Count / Size = 15,2
#         CFG Scale = 9  |  Seed = 85
#         Restore faces: True  |  Tilling: False  |  Hires.fix: False
#         Sampling method: DPM++ 2M SDE Karras   |   Sampling Steps: 120
#         Stable Diffusion Checkpoint: AbyssOrangeMix2
#         Other Advanced Settings: Default
#
#     # 問題点 / Issue
#         !Write Issue Here
#
#     # 傑作だと思うもの
#         !Write Masterpiece Here
#
# ![Sample](ipynb/part.14.png)

# %%
#@markdown Template Text Format Creator
print("If Not Changed.\nScript are importing From latest Markdown")
rsf = ""
tilling = ""
oas = ""
hfix = ""
x = input("1. Part Number: Part.")
part = str(x)
x = input("2. Paste Prompt: ")
prompt = str(x)
x = input("3. Paste Negative Prompt: ")
negative = str(x)
x = input("4. Enter Width: ")
w = str(x)
x = input("5. Enter Height: ")
h = str(x)
resolution = f"{w},{h}"
x = input("6. Batch Size: ")
batch_size = str(x)
x = input("7. Batch Count: ")
batch_count = str(x)
x = input("8. CFG Scale: ")
CFG = str(x)
x = input("9. Seed: ")
seed = str(x)
x = str(input("10. Restore Faces (0 or 1) (False or True)"))
if x == "0":
    rsf = "False"
elif x == "1":
    rsf = "True"
elif x == "False" or "True":
    rsf = str(x)
x = str(input("11. Tilling (0 or 1) (False or True)"))
if x == "0":
    tilling = "False"
elif x == "1":
    tilling = "True"
elif x == "False" or "True":
    tilling = str(x)
x = str(input("12. Hires.fix (0 or 1) (False or True)"))
if x == "0":
    hfix = "False"
elif x == "1":
    hfix = "True"
elif x == "False" or "True":
    hfix = str(x)
x = input("13. Sampling Method (Name): ")
sm = str(x)
x = input("14. Sampling Step: ")
ss = str(x)
x = str(input("15. You Write Other Advanced Settings?  (0 or 1): "))
if x == "0":
    overwrite = False
    oas = "Default"
elif x == "1":
    overwrite = True
    oas = str(input("""15. Enter Other Advanced Settings: \n"""))
extension = "png"
x = input("16. Stable Diffusion Checkpoint: ")
if x == "":
    sdcp = ""
else:
    sdcp = f"Stable Diffusion Checkpoint: {x}\n        "

# メイン生成
print(f"""
      \n\n\n
# Part {part}
    # Generate
        Prompt: {prompt}

        Negative Prompt: {negative} 
        
        Width, Height = {resolution}  |  Batch Count / Size = {batch_count},{batch_size}
        CFG Scale = {CFG}  |  Seed = {seed}
        Restore faces: {rsf}  |  Tilling: {tilling}  |  Hires.fix: {hfix}
        Sampling method: {sm}   |   Sampling Steps: {ss}
        {sdcp}Other Advanced Settings: {oas}

    # 問題点 / Issue
        # !Write Issue Here
        
    # 傑作だと思うもの
        # !Write Masterpiece Here
        
![Sample](ipynb/part.{part}.{extension})
\n\n\n\n\n""")
# Out:
# If Not Changed.
# Script are importing From latest Markdown
#
#
#
#
# # Part 12
#     # Generate
#         Prompt: - The character has waist-length black hair. - She is a girl named Ichika from Project Sekai. - She has black to light blue gradient eyes from the top. - She has white skin. - The background features a beautiful blue sky. - She is standing alone and smiling at us. - Her hair is a faint blue color in the light. - She has long, straight, waist-length black hair with bangs styled to keep them out of her eyes. - she is nude <lora:test:1>
#
# ...
